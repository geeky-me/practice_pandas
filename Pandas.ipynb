# %%
import pandas as pd
f=pd.read_csv("annual-enterprise-survey-2021-financial-year-provisional-csv.csv")
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_2556\3278548089.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
f
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
dict={
    'anjan':['a','b','c'],
    'number':[99,67,90]}
df=pd.DataFrame(dict)
df
# Out:
#   anjan  number
# 0     a      99
# 1     b      67
# 2     c      90

# %%
df.shape
# Out:
# (3, 2)

# %%
rows,col=df.shape

# %%
df.head()
# Out:
#   anjan  number
# 0     a      99
# 1     b      67
# 2     c      90

# %%
df.head(2)
# Out:
#   anjan  number
# 0     a      99
# 1     b      67

# %%
df.tail(2)
# Out:
#   anjan  number
# 1     b      67
# 2     c      90

# %%
df[1:2]
# Out:
#   anjan  number
# 1     b      67

# %%
df[:]
# Out:
#   anjan  number
# 0     a      99
# 1     b      67
# 2     c      90

# %%
df.columns
# Out:
# Index(['anjan', 'number'], dtype='object')

# %%
df.anjan
# or
df['anjan']
# Out:
# 0    a
# 1    b
# 2    c
# Name: anjan, dtype: object

# %%
type(df['number'])
# basically columns in pandas dataframe are series
# Out:
# pandas.core.series.Series

# %%
df[['anjan','number']]
# Out:
#   anjan  number
# 0     a      99
# 1     b      67
# 2     c      90

# %%
f
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
f['Year'].std()
# Out:
# 2.582019845995168

# %%
f.describe()#displays stats #only on integer like columns
# Out:
#               Year
# count  41715.00000
# mean    2017.00000
# std        2.58202
# min     2013.00000
# 25%     2015.00000
# 50%     2017.00000
# 75%     2019.00000
# max     2021.00000

# %%
f[f.Year>=2014]
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 37075  2014                     Level 3                 ZZ11
# 37076  2014                     Level 3                 ZZ11
# 37077  2014                     Level 3                 ZZ11
# 37078  2014                     Level 3                 ZZ11
# 37079  2014                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
f[f.Year==f.Year.max()]#give rows that have max year
# if it contains space use f[f['Year']==f['Year'].max()]
# Out:
#       Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0     2021                     Level 1                99999
# 1     2021                     Level 1                99999
# 2     2021                     Level 1                99999
# 3     2021                     Level 1                99999
# 4     2021                     Level 1                99999
# ...    ...                         ...                  ...
# 4630  2021                     Level 3                 ZZ11
# 4631  2021                     Level 3                 ZZ11
# 4632  2021                     Level 3                 ZZ11
# 4633  2021                     Level 3                 ZZ11
# 4634  2021                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# 0                 All industries  Dollars (millions)           H01
# 1                 All industries  Dollars (millions)           H04
# ...

# %%
f['Industry_code_NZSIOC'][f.Year==f.Year.max()]
# Out:
# 0       99999
# 1       99999
# 2       99999
# 3       99999
# 4       99999
#         ...
# 4630     ZZ11
# 4631     ZZ11
# 4632     ZZ11
# 4633     ZZ11
# 4634     ZZ11
# Name: Industry_code_NZSIOC, Length: 4635, dtype: object

# %%
f['Industry_code_NZSIOC'][f.Year==f.Year.max()]

# %%
f[['Year','Industry_code_NZSIOC']][f.Year==f.Year.max()]
# Out:
#       Year Industry_code_NZSIOC
# 0     2021                99999
# 1     2021                99999
# 2     2021                99999
# 3     2021                99999
# 4     2021                99999
# ...    ...                  ...
# 4630  2021                 ZZ11
# 4631  2021                 ZZ11
# 4632  2021                 ZZ11
# 4633  2021                 ZZ11
# 4634  2021                 ZZ11
#
# [4635 rows x 2 columns]

# %%
#search pandas series operations on google for more functions like min,max etc

# %%
df
# Out:
#   anjan  number
# 0     a      99
# 1     b      67
# 2     c      90

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
f.set_index('Year')#does not modify original dataframe
# Out:
#      Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# ...                          ...                  ...
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 2021              All industries  Dollars (millions)           H01
# 2021              All industries  Dollars (millions)           H04
# 2021              All industries  Dollars (millions)           H05
# ...

# %%
f.set_index('Year',inplace=True)

# %%
f
# Out:
#      Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# 2021                     Level 1                99999
# ...                          ...                  ...
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 2021              All industries  Dollars (millions)           H01
# 2021              All industries  Dollars (millions)           H04
# 2021              All industries  Dollars (millions)           H05
# ...

# %%
f.loc[2013]
# Out:
#      Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# Year
# 2013                     Level 1                99999
# 2013                     Level 1                99999
# 2013                     Level 1                99999
# 2013                     Level 1                99999
# 2013                     Level 1                99999
# ...                          ...                  ...
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
# 2013                     Level 3                 ZZ11
#
#             Industry_name_NZSIOC               Units Variable_code  \
# Year
# 2013              All industries  Dollars (millions)           H01
# 2013              All industries  Dollars (millions)           H04
# 2013              All industries  Dollars (millions)           H05
# ...

# %%
f.reset_index(inplace=True)#resets index to original

# %%
f
# Out:
#              Industry_name_NZSIOC  Year Industry_aggregation_NZSIOC  \
# 0                  All industries  2021                     Level 1
# 1                  All industries  2021                     Level 1
# 2                  All industries  2021                     Level 1
# 3                  All industries  2021                     Level 1
# 4                  All industries  2021                     Level 1
# ...                           ...   ...                         ...
# 41710  Food product manufacturing  2013                     Level 3
# 41711  Food product manufacturing  2013                     Level 3
# 41712  Food product manufacturing  2013                     Level 3
# 41713  Food product manufacturing  2013                     Level 3
# 41714  Food product manufacturing  2013                     Level 3
#
#       Industry_code_NZSIOC               Units Variable_code  \
# 0                    99999  Dollars (millions)           H01
# ...

# %%
f.set_index('Industry_name_NZSIOC',inplace=True)#u can use any column sort of like hash function where using that column as a hash key , u can get values associated with it.

# %%
f
# Out:
#                             Year Industry_aggregation_NZSIOC  \
# Industry_name_NZSIOC
# All industries              2021                     Level 1
# All industries              2021                     Level 1
# All industries              2021                     Level 1
# All industries              2021                     Level 1
# All industries              2021                     Level 1
# ...                          ...                         ...
# Food product manufacturing  2013                     Level 3
# Food product manufacturing  2013                     Level 3
# Food product manufacturing  2013                     Level 3
# Food product manufacturing  2013                     Level 3
# Food product manufacturing  2013                     Level 3
#
#                            Industry_code_NZSIOC               Units  \
# Industry_name_NZSIOC
# All industries                            99999  Dollars (millions)
# ...

# %%
f.reset_index(inplace=True)

# %% [markdown]
# DIFFERENT WAYS OF CREATING DATAFRAME

# %%
#USING read_csv
#using dictionary

# %%
#Excel file
df1=pd.read_excel("Book1.xlsx",'Sheet1')
# Out:
# C:\Users\Hp\AppData\Local\Temp\ipykernel_10588\2561804781.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df1
# Out:
#    id    name  marks
# 0   1   anjan     90
# 1   2    nonu     95
# 2   3  rajbir    100

# %%
#using tuples list
data=[
    (1,'anjan',90),
    (2,'nonu',95)
]

# %%
df=pd.DataFrame(data,columns=['id','name','marks'])

# %%
df
# Out:
#    id   name  marks
# 0   1  anjan     90
# 1   2   nonu     95

# %%
#using dictionaries list
data=[
    {'id':1,'name':'anjan'},
     {'id':2,'name':'nonu'}
]

# %%
df2=pd.DataFrame(data)
df2
# Out:
#    id   name
# 0   1  anjan
# 1   2   nonu

# %%
#google pandas io : take u to pandas documentation where u can see how to read dataframe from various sources

# %%
#read csv
